# %%
# pre setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
advertising_file_path = '../data/08-Linear-Regression-Models/Advertising.csv'

# %%
advertising = pd.read_csv(advertising_file_path)

# %%
advertising['total_spend'] = advertising['TV'] + advertising['radio'] + advertising['newspaper']

# %%
advertising.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.regplot(data=advertising, x='total_spend', y='sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = advertising['total_spend']
Y = advertising['sales']

# %%
np.polyfit(X, Y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(0, 500, 100)
predicted_sales = 0.04868788*potential_spend + 4.24302822

# %%
sns.scatterplot(data=advertising, x='total_spend', y='sales')
plt.plot(potential_spend, predicted_sales, color='red')

# %%
spend = 200
predicted = 0.04868788*spend + 4.24302822
predicted
# Out:
# 13.98060422

# %%
np.polyfit(X,Y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
pot_spend = np.linspace(0, 500, 100)
pred_sales = 3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2 + 8.20886302e-02*pot_spend + 2.70495053e+00

# %%
sns.scatterplot(data=advertising, x='total_spend', y='sales')
plt.plot(pot_spend, pred_sales, color='red')
